# %%
import requests
from bs4 import BeautifulSoup

url = "http://cafe.naver.com/malltail"
html = requests.get(url).text
soup = BeautifulSoup(html,"html.parser")
print(soup)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="ko">
# <head>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="requiresActiveX=true" http-equiv="X-UA-Compatible"/>
# <title>● 몰테일 스토리 - 쉽고 빠른 해외직구 ● : 네이버 카페</title>
# <link href="/favicon.ico?2" rel="shortcut icon" type="image/x-icon"/>
# <link href="/static/css/main/css/mycafe-common-1504521497000-56564.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/main/css/mycafe-layout-1504521497000-60618.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/main/css/line_sticker-1504521497000-9453.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/main/css/comment-1504521497000-16112.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/main/css/mycafe-main-1504521497000-213504.css" rel="stylesheet" type="text/css"/>
# ...

# %%
for tag in soup.select("box-g-m"):
    print(tag)

# %%
url
# Out:
# 'http://cafe.naver.com/malltail'

# %%
html
# Out:
# '<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\r\n\r\n<html lang="ko">\r\n<head>\r\n<meta name="robots" content="noindex, nofollow" />\r\n<meta http-equiv="Content-Type" content="text/html;charset=KSC5601">\r\n<meta http-equiv="X-UA-Compatible" content="requiresActiveX=true">\r\n<title>● 몰테일 스토리 - 쉽고 빠른 해외직구 ● : 네이버 카페</title>\r\n\n\n<link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?2" />\r\n<link rel="stylesheet" href="/static/css/main/css/mycafe-common-1504521497000-56564.css" type="text/css">\n\r\n<link rel="stylesheet" href="/static/css/main/css/mycafe-layout-1504521497000-60618.css" type="text/css">\n\r\n<link rel="stylesheet" href="/static/css/main/css/line_sticker-1504521497000-9453.css" type="text/css">\n\r\n<link rel="stylesheet" href="/static/css/main/css/comment-1504521497000-16112.css" type="text/css">\n\r\n<link rel="stylesheet" href="/static/css/main/css/mycafe-main-1504521497000-213504.css" type="t
# ...

# %%
url_2 = "http://sminkim.mireene.com/"

# %%
html_2 = request.get(url_2).text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3ea9a28ac087> in <module>()
# ----> 1 html_2 = request.get(url_2).text
#
# NameError: name 'request' is not defined

# %%
html_2 = requests.get(url_2).text

# %%
html_2
# Out:
# '104d\r\n<html>\r\n<head>\r\n<meta http-equiv="content-type" content="text/html; charset=euc-kr">\r\n<title>Prof. Kim, sungmin\'s Finance &amp; Banking LAB.</title>\r\n<meta name="generator" content="Namo WebEditor v6.0">\r\n\r\n\r\n<script language="JavaScript"><!--\r\nfunction namosw_goto_byselect(sel, targetstr)\r\n{\r\n  var index = sel.selectedIndex;\r\n  if (sel.options[index].value != \'\') {\r\n     if (targetstr == \'blank\') {\r\n       window.open(sel.options[index].value, \'win1\');\r\n     } else {\r\n       var frameobj;\r\n       if (targetstr == \'\') targetstr = \'self\';\r\n       if ((frameobj = eval(targetstr)) != null)\r\n         frameobj.location = sel.options[index].value;\r\n     }\r\n  }\r\n}\r\n\r\n// --></script><script language="JavaScript"><!--\r\nfunction na_restore_img_src(name, nsdoc)\r\n{\r\n  var img = eval((navigator.appName.indexOf(\'Netscape\', 0) != -1) ? nsdoc+\'.\'+name : \'document.all.\'+name);\r\n  if (name == \'\')\r\n    return;\r\n  if (
# ...
